# %%
import requests
import pandas as pd
from sqlalchemy import create_engine

# Your API key (replace 'your_api_key_here' with the actual key)
api_key = 'FBIf05aG71f7zZt2jGk2eXHxDjvmEdp2BCKfFMiZ'

# Define the base URL for the SportsRadar API (adjust this based on the API docs)
url = f'https://api.sportradar.com/mma/trial/v2/en/competitions.json?api_key=FBIf05aG71f7zZt2jGk2eXHxDjvmEdp2BCKfFMiZ'

# Make a request to the API
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    ufc_data = response.json()
    print(ufc_data)  # View the raw data returned by the API
else:
    print(f"Failed to retrieve data: {response.status_code}")
# Out:
# {'generated_at': '2024-10-31T00:13:27+00:00', 'competitions': [{'id': 'sr:competition:25357', 'name': 'UFC Contender Series, Las Vegas, Week 26', 'parent_id': 'sr:competition:25325', 'category': {'id': 'sr:category:1089', 'name': 'UFC'}}, {'id': 'sr:competition:25399', 'name': 'UFC Fight Night - Boise, Idaho', 'parent_id': 'sr:competition:25325', 'category': {'id': 'sr:category:1089', 'name': 'UFC'}}, {'id': 'sr:competition:25455', 'name': 'UFC 226 - Las Vegas', 'parent_id': 'sr:competition:25325', 'category': {'id': 'sr:category:1089', 'name': 'UFC'}}, {'id': 'sr:competition:25457', 'name': 'The Ultimate Fighter Finale - Las Vegas, week 27', 'parent_id': 'sr:competition:25325', 'category': {'id': 'sr:category:1089', 'name': 'UFC'}}, {'id': 'sr:competition:25517', 'name': 'UFC Contender Series, Las Vegas, Week 28', 'parent_id': 'sr:competition:25325', 'category': {'id': 'sr:category:1089', 'name': 'UFC'}}, {'id': 'sr:competition:25613', 'name': 'UFC Fight Night - St. Louis', 'parent_
# ...

# %%
# Convert the relevant part of the JSON data to a DataFrame (adjust based on the structure of the API response)
# For example, assuming the data contains a 'competitions' key:
if 'competitions' in ufc_data:
    df = pd.DataFrame(ufc_data['competitions'])
    print(df.head())  # Display the first few rows
# Out:
#                      id                                              name  \
# 0  sr:competition:25357          UFC Contender Series, Las Vegas, Week 26
# 1  sr:competition:25399                    UFC Fight Night - Boise, Idaho
# 2  sr:competition:25455                               UFC 226 - Las Vegas
# 3  sr:competition:25457  The Ultimate Fighter Finale - Las Vegas, week 27
# 4  sr:competition:25517          UFC Contender Series, Las Vegas, Week 28
#
#               parent_id                                   category
# 0  sr:competition:25325  {'id': 'sr:category:1089', 'name': 'UFC'}
# 1  sr:competition:25325  {'id': 'sr:category:1089', 'name': 'UFC'}
# 2  sr:competition:25325  {'id': 'sr:category:1089', 'name': 'UFC'}
# 3  sr:competition:25325  {'id': 'sr:category:1089', 'name': 'UFC'}
# 4  sr:competition:25325  {'id': 'sr:category:1089', 'name': 'UFC'}

# %%
# Connect to PostgreSQL using SQLAlchemy
engine = create_engine('postgresql://postgres:password@localhost/ufc_stats')

# Load the DataFrame into a PostgreSQL table (replace 'competitions' with your actual table name)
df.to_sql('competitions', engine, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2118, in Connection._exec_insertmany_context(self, dialect, context)
#    2117     else:
# -> 2118         dialect.do_execute(
#    2119             cursor,
#    2120             sub_stmt,
#    2121             sub_params,
#    2122             context,
#    2123         )
#    2125 except BaseException as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sqlalchemy/engine/default.py:941, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     940 def do_execute(self, cursor, statement, parameters, context=None):
# --> 941     cursor.execute(statement, parameters)
#
# ProgrammingError: can't adapt type 'dict'
#
# ...

# %%
print(df.head())  # Display the first few rows
print(f"Number of rows: {len(df)}")  # Display the total number of rows
# Out:
#                      id                                              name  \
# 0  sr:competition:25357          UFC Contender Series, Las Vegas, Week 26
# 1  sr:competition:25399                    UFC Fight Night - Boise, Idaho
# 2  sr:competition:25455                               UFC 226 - Las Vegas
# 3  sr:competition:25457  The Ultimate Fighter Finale - Las Vegas, week 27
# 4  sr:competition:25517          UFC Contender Series, Las Vegas, Week 28
#
#               parent_id                                   category
# 0  sr:competition:25325  {'id': 'sr:category:1089', 'name': 'UFC'}
# 1  sr:competition:25325  {'id': 'sr:category:1089', 'name': 'UFC'}
# 2  sr:competition:25325  {'id': 'sr:category:1089', 'name': 'UFC'}
# 3  sr:competition:25325  {'id': 'sr:category:1089', 'name': 'UFC'}
# 4  sr:competition:25325  {'id': 'sr:category:1089', 'name': 'UFC'}
# Number of rows: 361

# %%
from sqlalchemy import create_engine

# Create a connection to PostgreSQL
engine = create_engine('postgresql://postgres:password@localhost/ufc_stats')

# Insert the DataFrame into PostgreSQL
df.to_sql('competitions', engine, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2118, in Connection._exec_insertmany_context(self, dialect, context)
#    2117     else:
# -> 2118         dialect.do_execute(
#    2119             cursor,
#    2120             sub_stmt,
#    2121             sub_params,
#    2122             context,
#    2123         )
#    2125 except BaseException as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sqlalchemy/engine/default.py:941, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     940 def do_execute(self, cursor, statement, parameters, context=None):
# --> 941     cursor.execute(statement, parameters)
#
# ProgrammingError: can't adapt type 'dict'
#
# ...

# %%
print(df.dtypes)  # Check the data types of all columns
print(df.head())  # Display the first few rows to get a sense of the data
# Out:
# id           object
# name         object
# parent_id    object
# category     object
# dtype: object
#                      id                                              name  \
# 0  sr:competition:25357          UFC Contender Series, Las Vegas, Week 26
# 1  sr:competition:25399                    UFC Fight Night - Boise, Idaho
# 2  sr:competition:25455                               UFC 226 - Las Vegas
# 3  sr:competition:25457  The Ultimate Fighter Finale - Las Vegas, week 27
# 4  sr:competition:25517          UFC Contender Series, Las Vegas, Week 28
#
#               parent_id                                   category
# 0  sr:competition:25325  {'id': 'sr:category:1089', 'name': 'UFC'}
# 1  sr:competition:25325  {'id': 'sr:category:1089', 'name': 'UFC'}
# 2  sr:competition:25325  {'id': 'sr:category:1089', 'name': 'UFC'}
# 3  sr:competition:25325  {'id': 'sr:category:1089', 'name': 'UFC'}
# 4  sr:competition:25325  {'id': 'sr:category:1089', 'name': 'UFC'}

# %%
df = df.drop(columns=['category'])

# %%
print(df.dtypes)  # Check the data types of all columns
print(df.head())  # Display the first few rows to get a sense of the data
# Out:
# id           object
# name         object
# parent_id    object
# dtype: object
#                      id                                              name  \
# 0  sr:competition:25357          UFC Contender Series, Las Vegas, Week 26
# 1  sr:competition:25399                    UFC Fight Night - Boise, Idaho
# 2  sr:competition:25455                               UFC 226 - Las Vegas
# 3  sr:competition:25457  The Ultimate Fighter Finale - Las Vegas, week 27
# 4  sr:competition:25517          UFC Contender Series, Las Vegas, Week 28
#
#               parent_id
# 0  sr:competition:25325
# 1  sr:competition:25325
# 2  sr:competition:25325
# 3  sr:competition:25325
# 4  sr:competition:25325

# %%
df = df.drop(columns=['parent_id'])

# %%
print(df.dtypes)  # Check the data types of all columns
print(df.head())  # Display the first few rows to get a sense of the data
# Out:
# id      object
# name    object
# dtype: object
#                      id                                              name
# 0  sr:competition:25357          UFC Contender Series, Las Vegas, Week 26
# 1  sr:competition:25399                    UFC Fight Night - Boise, Idaho
# 2  sr:competition:25455                               UFC 226 - Las Vegas
# 3  sr:competition:25457  The Ultimate Fighter Finale - Las Vegas, week 27
# 4  sr:competition:25517          UFC Contender Series, Las Vegas, Week 28

# %%
# Convert columns to string if they contain complex objects
df['id'] = df['id'].astype(str)

# %%
# Convert columns to string if they contain complex objects
df['name'] = df['name'].astype(str)

# %%
print(df.dtypes)  # Check the data types of all columns
print(df.head())  # Display the first few rows to get a sense of the data
# Out:
# id      object
# name    object
# dtype: object
#                      id                                              name
# 0  sr:competition:25357          UFC Contender Series, Las Vegas, Week 26
# 1  sr:competition:25399                    UFC Fight Night - Boise, Idaho
# 2  sr:competition:25455                               UFC 226 - Las Vegas
# 3  sr:competition:25457  The Ultimate Fighter Finale - Las Vegas, week 27
# 4  sr:competition:25517          UFC Contender Series, Las Vegas, Week 28

# %%
df.to_sql('competitions', engine, if_exists='replace', index=False)
# Out:
# 361

# %%
# Check for missing values
missing_values = df.isnull().sum()
print("Missing values per column:\n", missing_values)
# Out:
# Missing values per column:
#  id      0
# name    0
# dtype: int64

# %%
# Check for duplicates
duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")

# Drop duplicates if any
df = df.drop_duplicates()
# Out:
# Number of duplicate rows: 0

# %%
# Check data types
print(df.dtypes)
# Out:
# id      object
# name    object
# dtype: object

# %%
import requests

url = "https://api.sportradar.com/mma/trial/v2/en/competitors/sr%3Acompetitor%3A237652/profile.json?api_key=FBIf05aG71f7zZt2jGk2eXHxDjvmEdp2BCKfFMiZ"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"generated_at":"2024-10-31T00:57:57+00:00","competitor":{"id":"sr:competitor:237652","name":"Holloway, Max","abbreviation":"HOL","gender":"male"},"info":{"birth_city":"Honolulu","birth_state":"HI","birth_country":"UNITED STATES","birth_country_code":"USA","birth_date":"1991-12-04","fighting_out_of_city":"Waianae","fighting_out_of_country":"UNITED STATES","fighting_out_of_country_code":"USA","fighting_out_of_state":"HI","reach":175,"height":180,"weight":70.8,"nickname":"Blessed"},"record":{"wins":26,"draws":0,"losses":8}}
